# %% [markdown]
# # 第3章 管理和使用容器
#
# 在Docker中，容器是基于镜像运行的轻量级环境，是Docker封装和管理应用程序或微服务的“集装箱”。运行中的容器读取了镜像中基础的程序和依赖库的代码，并将修改保存在一个沙盒环境中，充分保障了应用程序运行的虚拟性和隔离性。
#
# 容器作为Docker的核心组件，熟悉掌握容器的操作是使用Docker不可或缺的技能，在本章中，我们就专门介绍DockerDocker容器的使用。我们将了解到容器的创建、终止、删除等基本操作，以及如何查看运行在容器中的应用程序的状态，如何导入、导出和迁移容器。

# %% [markdown]
# ## 3.1 管理容器
#
# 要掌握容器的使用方法，就要了解管理Docker容器的基本方法。作为容器技术的核心模块，Docker为我们提供了非常丰富的对容器的操作，这些操作足以让我们创建、启动、停止和了解容器的运行状况。

# %% [markdown]
# ### 3.1.1 创建容器
#
# 所有的容器操作都离不开容器，容器是在镜像的基础上建立的运行态，要创建容器，可以使用docker create命令。创建容器的命令非常简单，将容器所基于的镜像名称传入即可。Docker会从本地镜像仓库中找到给定的镜像，如果未找到本地镜像，也会自动从远程镜像仓库中下载需要的镜像。这里，我们创建一个运行Debian的容器：
#
# ![image.png](attachment:8151dec3-2ac1-48fc-aa51-727499bc8578.png)

# %%
#对应图片images/txt004_1.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sudo docker create debian: jessie

2e4ee3689de6f047008af45e95£1993688e5al16e500c55201lala8d0d
# Out:
#   File "<ipython-input-10-fd13f9c68b9f>", line 2
#     S sudo docker create debian: jessie
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_1.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 当容器创建完成后，Docker会马上将容器的ID输出到屏幕上。容器的ID与镜像ID类似，是可以识别容器唯一性的属性，显示为长度为64位的十六进制字符串。每个容器的ID都是独一无二的，即使它们基于同一个镜像创建。
#
# 容器的ID能够识别容器的唯一性，这在需要指定容器的时候显得非常重要。在很多场合下，我们也能像在镜像操作中给出部分镜像ID一样，使用容器ID的前一部分，只要我们能够确保给出的部分ID在本地主机所有的容器中对应唯一的容器即可。
#
# Docker容器是针对运行单一的应用程序设计的，对于容器生命周期的控制，Docker通过将其与进程的生命周期进行绑定来实现。虽然Docker容器中能够运行多个进程乃至多个不同的程序，但在设计上应该只以一个应用程序为主体，其他程序只是为这个主体提供支持。容器启动时，一个被我们指定的程序也会被启动，Docker会监视这个程序的主进程，当这个进程退出时，容器也会停止运行。而当我们通过命令来停止容器运行时，Docker会发送停止信号给这个进程，让程序结束。
#
# * [选择题★★ 关于生命周期，以下哪个说法有误？](https://xue.cn/hub/app/exercise/1867)
#
# 在大多数镜像中，镜像的制作者已经给定了基于这个镜像的容器在启动时索要运行的程序，也可以在创建容器的同时重新指定容器所绑定的应用程序。通过在指定进程名称和后面携带程序名称和参数，就能实现重新绑定主应用程序了：
#
# ![image.png](attachment:1bf9164d-7959-44bc-8ace-16c5b501bbec.png)

# %%
#对应图片images/txt004_2.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sudo docker create debian:jessie tail -f /var/log/faillog
# Out:
#   File "<ipython-input-11-8f0fcfdcdc2c>", line 2
#     S sudo docker create debian:jessie tail -f /var/log/faillog
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_2.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 需要注意的是，Docker容器只会绑定一个进程，所以我们重新指定的进程会覆盖镜像原本设置的应用程序绑定。如果应用程序依赖于其他程序的支持，而这些程序也需要放置和运行在同一个容器中，我们可以通过容器入口来运行这些程序。
#
# 了解了容器的创建，接下来要了解的就是运行容器。需要注意的是，Docker和其他虚拟机类似，创建容器只是配置了容器的文件系统和网络等基础资源，并不代表容器及容器中应用程序已经在运行了。
#
# 若要在创建容器的同时就让容器运行起来，需要使用docker run命令，其与docker create命令很相似。
#
# ![image.png](attachment:0e2e3e0d-6b66-4a65-a8e1-40b0e436d869.png)

# %%
#对应图片images/txt004_3.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker run debian: jessie
# Out:
#   File "<ipython-input-12-0db109c4f287>", line 2
#     S$ sudo docker run debian: jessie
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_3.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# Docker容器有以下两种运行态。
#
# ❑ 前台交互式：容器运行在前台，容器运行时直接连接到了程序中运行的程序上，当我们通过命令退出和关闭连接的程序时，就意味着容器停止了运行。在这种场景下，我们通常会通过附加的参数打开容器的伪终端和输入流，这样我们就可以和容器中的程序实现交互了。
#
# ❑ 后台守护式：容器运行在后台，运行的过程不会占用到当前输入指令的终端，也不会连接到容器内的应用程序上。因为我们无法连接到容器中的程序，所以处于这种运行态的容器必须通过指令来关闭。
#
# 在默认情况下，如果我们在使用docker run命令的时候没有显式指定容器的运行态，容器会以前台交互的形式运行，输入命令的终端会被挂起，其实这时我们已经连接到了容器中正在运行的应用程序上，当我们使用“Ctrl+C”组合键发出程序终止信号后，程序会随之停止，容器也会随着程序的结束而终止。
#
# 虽然容器在前台运行，但我们只是连接到了容器中的应用程序，并没有形成与应用程序完整的交互，要与容器形成完整的交互，还需要使用-t和-i两个参数。在docker run命令中携带-t或--tty参数，可以让Docker为这个容器分配一个伪终端，为实现交互提供基础。而带入-i或--interactive则打开了交互模式，这时候输入流会一直保持，以便我们向容器中输入命令或数据。
#
# 这里通过Bash进入Debian系统，并通过-i和-t准备好交互模式：
#
# ![image.png](attachment:31269e19-fda6-4016-9d00-18dc24943a54.png)

# %%
#对应图片images/txt004_4.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sudo docker run -i -t debian:jessie /bin/bash

rootld43c4a3361e0:/#
# Out:
#   File "<ipython-input-13-0a9b2e591c1c>", line 2
#     S sudo docker run -i -t debian:jessie /bin/bash
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_4.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 执行命令后，容器中的Bash就在等待输入指令了。通过检查系统版本，可以查看我们是否已经进入到了容器中：
#
# ![image.png](attachment:d12bad16-2202-46f1-9567-a732660a9012.png)

# %%
#对应图片images/txt004_5.jpg；想要获取 mycode 奖励，请勿删除此行注释。
root0d43c4a3361le0:/# uname -a
Linux d43c4a3361le0 4.4.15-moby #1 SMP Thu Jul 28 21:30:50 UTC 2016 x86_64 GNU/Linux
# Out:
#   File "<ipython-input-14-26c41f33329f>", line 2
#     root0d43c4a3361le0:/# uname -a
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_5.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 在容器中执行完操作之后，可以使用exit终止Bash程序，容器也会随之停止，我们就回到了宿主机中：
#
# ![image.png](attachment:035bca13-b675-4698-a9e4-414628501ac1.png)

# %%
#对应图片images/txt004_6.jpg；想要获取 mycode 奖励，请勿删除此行注释。
rootd43c4a3361le0:/# exit
exit

$
# Out:
#   File "<ipython-input-15-a58a4c3ba000>", line 2
#     rootd43c4a3361le0:/# exit
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_6.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 因为Docker在更多场合下是用于部署服务程序的，所以我们需要通过-d指令让容器运行在后台，这样不会占用和阻塞当前输入命令的终端，当我们退出终端后，容器仍会继续运行下去。
#
# ![image.png](attachment:c69a0951-7cce-44b1-9396-2e7bd55f985d.png)

# %%
#对应图片images/txt004_7.jpg；想要获取 mycode 奖励，请勿删除此行注释。
$ sudo docker run -d nginx:1.10
# Out:
#   File "<ipython-input-16-1045031ba4dd>", line 2
#     $ sudo docker run -d nginx:1.10
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_7.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 我们无法让容器在前后台同时运行，所以我们也就不能同时传入-d和-i参数，这两者是会产生冲突的。
#
# 小提示：在使用Docker CLI时，一些命令参数是可以进行组合的，比如-i和-t参数可以简写为-it，两者的效果是完全一样的。

# %% [markdown]
# ### 3.1.2 容器的启动过程
#
# 在我们创建容器时，Docker会先检查本地镜像库中是否有指定用于创建容器的镜像，如果没有在本地镜像库中找到镜像，Docker会先从远程仓库中查找并下载到本地。接着，Docker会创建容器的实例，将镜像以只读的方式挂载在为容器分配的文件系统上，并在只读镜像层的外侧，创建一个读写的层。之后，Docker会配置容器的网络，连接到宿主机中专用的网桥，并为容器分配网络地址。
#
# 当我们启动已经创建好的容器时，所指定的应用程序会被运行，且容器会绑定到这个程序的启动进程上。当容器所绑定的进程结束时，容器也会随之停止。图 3-1 展示了容器启动和执行的过程。
#
# ![image.png](attachment:f6ca2726-5c10-4bda-89d6-dcc61d3be75e.png)
#
# 图3-1　容器启动和执行的过程

# %% [markdown]
# ### 3.1.3 列出容器
#
# 在Linux中，我们可以使用ps命令来查看系统中运行的进程；而在Docker中，我们也能通过docker ps命令来查看所有的容器。
#
# ![image.png](attachment:62de9917-50a3-4c8c-86aa-e96249053586.png)

# %%
#对应图片images/txt004_9.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker ps

CONTAINER ID IMAGE COMMAND
PORTS NAMES
8a13693f2ba6 nginx:1.10 "nginx -g 'daemon off"

443/tcp, 0.0.0.0:8080->80/tep nginx
2a987e2d07153 php: 7-fpm "php-fpm"
9000/tcp phpfpm

CREATED

2 weeks ago

2 weeks ago

STATUS

Up 6 seconds

Up 7 seconds
# Out:
#   File "<ipython-input-17-478bf58c6f6a>", line 2
#     S$ sudo docker ps
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_9.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 在docker ps命令输出的字段中，可以看到以下信息。
#
# ❑ CONTAINER ID：容器ID。
#
# ❑ IMAGE：容器所使用的镜像名称。
#
# ❑ COMMAND：启动容器时应用程序的指令。
#
# ❑ CREATED：容器的创建时间。
#
# ❑ STATUS：容器运行的状态和更新状态的时间。Up表示容器正在运行，如果容器处于暂停状态，会在表示状态的Up和状态的更新时间后，存在Paused字样。而Exited表示容器已经退出，在之后会有容器内关联进程退出的返回值。
#
# ❑ PORTS：容器对外敞开的端口，我们会在后面专门介绍容器对外的端口和如何配置容器间的网络访问。
#
# ❑ NAMES：容器的名称，是我们识别容器的另一种方式。
#
# 使用docker ps命令只会列出正在运行中的容器，如果要列出所有容器，可以通过携带-a或--all参数来实现。
#
# ![image.png](attachment:4727627d-b2f4-4fa8-99d0-ff6b90d25d43.png)

# %%
#对应图片images/txt004_10.jpg；想要获取 mycode 奖励，请勿删除此行注释。
$ sudo docker ps -a

CONTAINER ID
STATUS
8al3693f2ba6

Up 2 hours
2a987e2d07153

Up 2 hours
96ab436b10bb

Exited (0)

IMAGE COMMAND
PORTS
nginx:1.10 "nginx -g 'daemon off"
443/tcp, 0.0.0.0:8080—->80/tcp
php: 7-fpm "php-fpm"
9000/tcp
ubuntu "/bin/bash"

13 seconds ago

CREATED
NAMES

2 weeks ago
nginx

2 weeks ago
phpfpm

2 weeks ago

ubuntu
# Out:
#   File "<ipython-input-18-787afb5d4263>", line 2
#     $ sudo docker ps -a
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_10.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 由上可以看到，列出的容器中出现了已经停止的容器，在容器状态里，显示为Exited(0) 13 seconds ago。其中，Exited(0)中的0表示容器结束时主进程的退出码，通常情况下为正常退出；13 seconds ago表示容器上次更新状态的时间，也就是容器退出的时间。
#
# 当我们创建了较多容器时，使用docker ps命令会返回非常多的结果，在密集的结果中找到想要查看的容器并不是一件容易的事情，此时可以通过一些参数对docker ps的结果进行过滤。
#
# 使用-l或--latest参数可以列出最后创建的容器：
#
# ![image.png](attachment:6dc21b15-5560-4064-8387-4a85b860f80d.png)

# %%
#对应图片images/txt004_11.jpg；想要获取 mycode 奖励，请勿删除此行注释。
§$ sudo docker ps -l

CONTAINER ID IMAGE COMMAND
PORTS NAMES
Sal 3693f2Zba6 nginx:1.10 "nginx -g 'daemon off"

443) Co. 020.0: 8080>>80)/ tep nginx

CREATED

2 weeks ago

STATUS

Up 2 hours
# Out:
#   File "<ipython-input-19-9813594d2486>", line 2
#     §$ sudo docker ps -l
#     ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_11.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 使用-n <n>或--last <n>参数可以列出数个最近创建的容器：
#
# ![image.png](attachment:f6b132b5-005f-4176-9bd0-3c9adafa3ba7.png)

# %%
#对应图片images/txt004_12.jpg；想要获取 mycode 奖励，请勿删除此行注释。
$ sudo docker ps -n 2

CONTAINER ID IMAGE COMMAND
PORTS NAMES
8al3693f2ba6 nginx:1.10 "nginx -g 'daemon off"
443/ tcp, 0.0.0.0: 808 0>>8 0/ tep nginx
2a987e2d07153 php: 7-fpm "php-fpm"

9000/tcp phpfpm

CREATED

2 weeks ago

2 weeks ago

STATUS

Up 2 hours

Up 2 hours
# Out:
#   File "<ipython-input-20-4252209c73cc>", line 2
#     $ sudo docker ps -n 2
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_12.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 使用-f "key=value"或者--filter "key=value"参数可以进行多种形式的过滤，例如过滤容器的名称：
#
# ![image.png](attachment:0c6c8f3a-32da-43ca-9c27-fd95f06a3562.png)

# %%
#对应图片images/txt004_13.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sudo docker ps -f "name=phpfpm"
CONTAINER ID IMAGE COMMAND CREATED STATUS PORTS NAMES
2a987e2d7153 php:7-fpm "php-fpm" 2 weeks ago Up 2 hours 9000/tcp phpfpm
# Out:
#   File "<ipython-input-21-fb241b750d9f>", line 2
#     S sudo docker ps -f "name=phpfpm"
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 图片：images/txt004_13.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 过滤的方式有很多种，都是在-f参数之后连接key=value的，进行多种过滤可以连用多个-f参数来实现，以下是可以被使用的过滤方式的键名（key）。
#
# ❑ id：容器的ID。
#
# ❑ label：容器的标记，可以来源于创建容器的镜像，也可以在使用docker create 或docker run创建容器时通过--label参数带入。
#
# ❑ name：容器的名称。
#
# ❑ exited：容器停止时主进程的返回码，进行exited过滤时需要同时使用-a或者--all确保查询到所有的容器。
#
# ❑ status：容器的状态，可以为created（已创建）、restarting（重启中）、running（运行中）、paused（暂停中）、exited（已停止）、dead（已结束）。
#
# ❑ ancestor：创建容器的镜像，可以指定镜像名或镜像ID。
#
# ❑ before：给出一个容器名或容器ID，返回所有在给定容器之前创建的容器。
#
# ❑ since：给出一个容器名或容器ID，返回所有在给定容器之后创建的容器。
#
# ❑ isolation：隔离性，可以为default（默认）、process（进程隔离）、hyperv（虚拟机隔离），这个参数只对Windows中的Docker有效。
#
# ❑ volume：给出数据卷的名称或挂载点，返回使用指定数据卷的容器。
#
# ❑ network：给出网络ID或网络名称，返回连接到指定网络的容器。

# %% [markdown]
# ### 3.1.4 容器的命名
#
# 在docker ps列出的容器信息中，可以看到NAMES字段，即容器的名称。容器名称与镜像名称类似，也是除容器ID以外另一种识别容器的方式，在同一个docker daemon下，容器名称是唯一的，在进行大部分操作时，可以使用容器名称来替代容器ID。
#
# 给容器命名最大的好处就是名称是一个可以表意的字符串，相较于随机生成的容器ID，其可读性更高。可以使用表示容器用途的名字为容器命名，方便我们进行记忆。
#
# 在默认情况下，如果我们没有为创建的容器命名，Docker会用单词组合的形式为容器取一个随机的名字。
#
# ![image.png](attachment:7a75106e-c046-459b-9ec7-22d77ed784d1.png)

# %%
#对应图片images/txt004_14.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudu docker run -d nginx:stable
1014a82£7c2£1d3a9371bd4abcc62£3992786f4elaa78£469d2c109ad2a25c2b

$ sudo docker ps -l

CONTAINER ID IMAGE COMMAND CREATED
STATUS PORTS NAMES
1014a82f£7c2£ nginx:stable "nginx -g 'daemon off" 4 seconds ago

Up 3 seconds 80/tcp, 443/tcp modest_jang
# Out:
#   File "<ipython-input-22-a4e8ee5ce200>", line 2
#     S$ sudu docker run -d nginx:stable
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_14.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 这样随机生成的名字虽然有一定的含义，但还不能完全达到我们的目的。在创建容器时给出--name <name>参数，可以自定义被创建容器的名称。
#
# ![image.png](attachment:1fd31800-03b2-46d4-82e4-8cbedf68453f.png)

# %%
#对应图片images/txt004_15.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker run -d --name web nginx:stable
efcd69e060ee3107853b£58052b7665299277fbecbhd13c2370c7£b2350700417
$ sudo docker ps -l

CONTAINER ID IMAGE COMMAND CREATED
STATUS PORTS NAMES
efcd69e060ee nginx:stable "nginx -g 'daemon off" 3 seconds ago

Up 1 seconds 80/tcp, 443/tcp web
# Out:
#   File "<ipython-input-23-1b606db31555>", line 2
#     S$ sudo docker run -d --name web nginx:stable
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_15.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 给容器命名还可以为我们之后建立容器间的互相依赖关系提供方便。例如，我们需要建立Nginx
#
# * PHP + MySQL的服务器架构，可以把三个容器分别命名为nginx、php、mysql，这样在处理依赖时，我们可以很方便地指定Nginx容器连接到PHP容器、PHP容器连接到MySQL容器。在进行容器连接和数据共享时，清晰的依赖关系是达到目的的关键。

# %% [markdown]
# ### 3.1.5 启动和停止
#
# 我们可以通过docker run命令来创建并启动容器，但我们还需要启动通过docker create命令创建的容器，以及启动已经停止的容器，这时就需要使用docker start命令了。
#
# ![image.png](attachment:e59e7256-1d38-432d-8eae-997dffc53c33.png)

# %%
#对应图片images/txt004_16.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker start web

web
# Out:
#   File "<ipython-input-24-01cbc2835100>", line 2
#     S$ sudo docker start web
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_16.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 使用docker start命令时，可以传入我们为容器设置的名字，也可以传入容器的ID，当我们传入容器ID时，可以只传入容器ID的前一部分，只要能够判断容器在Docker中的唯一性即可。
#
# ![image.png](attachment:309a41c5-8755-44ce-abae-4f83853136c3.png)

# %%
#对应图片images/txt004_17.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker start 8a136
8al36
# Out:
#   File "<ipython-input-25-95e0bef325b2>", line 2
#     S$ sudo docker start 8a136
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_17.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 如果容器启动顺利，我们可以在终端中看到docker start命令返回的结果，即我们所使用的容器名称或容器ID。
#
# 在默认情况下，容器会以后台守护的方式启动运行，当然我们也可以切换到交互模式。在启动容器时使用-i或--interactive参数，可以将终端连接到容器中主应用程序的标准输入上，而携带-a或-attach参数，则可以将容器中程序的标准输入及错误输出的结果，显示到终端中。
#
# 如果容器组成了一套服务体系，我们可以使用一条docker start命令来启动它们，只要逐个传入容器名称或容器ID到docker start命令中即可。
#
# ![image.png](attachment:c64344e7-4ade-4bf6-b116-3fc5d1fdc4a4.png)

# %%
#对应图片images/txt004_18.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker start nginx phpfpm mysql
nginx

phpfpm

mysql
# Out:
#   File "<ipython-input-26-ccfb6c008241>", line 2
#     S$ sudo docker start nginx phpfpm mysql
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_18.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 使用docker stop命令可以停止正在运行中的容器，当我们发出docker stop命令时，Docker会向容器所绑定的主要进程发送SIGTERM信号，告知程序自行停止。如果程序在限定的时间内没有自动停止，则Docker会发送SIGKILL信号强制结束进程。如我们之前提到的，容器的生命周期是与主进程绑定的，所以在主进程结束后，容器也就停止了。
#
# ![image.png](attachment:12db17ba-4311-4292-a2ac-44eec78d9fba.png)

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_19.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# Docker提供给程序自行退出的默认时间是10秒，我们也可以通过传入-t或--time参数来更改这个时间。
#
# ![image.png](attachment:934b6677-b710-479b-9f4f-e2cb2faf894c.png)

# %%
#对应图片images/txt004_20.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sudo docker stop -t 3 web

web
# Out:
#   File "<ipython-input-27-cc179b765470>", line 2
#     S sudo docker stop -t 3 web
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_20.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 另外，Docker还提供了docker kill命令来直接停止容器，docker kill命令会直接发送SIGKILL信号强制结束容器的主进程。
#
# ![image.png](attachment:bf022b0d-d8d1-456a-b7da-21771b9cc608.png)

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_21.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 被docker kill命令传递到容器中的信号是可以自定义的，也可以通过传入-s或--signal参数定义被使用在进程上的信号。
#
# ![image.png](attachment:640ab71c-ea7d-45e2-8151-0a5d36ec2603.png)

# %%
#对应图片images/txt004_22.jpg；想要获取 mycode 奖励，请勿删除此行注释。
§ sudo docker kill -s INT web

web
# Out:
#   File "<ipython-input-28-397a23bd4cca>", line 2
#     § sudo docker kill -s INT web
#     ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_22.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 与docker start命令的作用一样，使用docker stop命令也可以同时传入多个容器：
#
# ![image.png](attachment:f6a717c8-6014-4437-ad1c-c91aea31dda0.png)

# %%
#对应图片images/txt004_23.jpg；想要获取 mycode 奖励，请勿删除此行注释。
$ sudo docker stop nginx phpfpm mysql
nginx

phpfpm

mysql
# Out:
#   File "<ipython-input-29-4401d3850757>", line 2
#     $ sudo docker stop nginx phpfpm mysql
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_23.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00

# %% [markdown]
# ### 3.1.6 暂停和恢复
#
# 除了启动和停止容器，我们还可以让容器暂停或恢复，使用docker pause和docker unpause命令可以分别暂停和恢复容器的运行。
#
# 暂停容器与停止容器最大的区别在于，停止容器时容器中运行的应用程序也会一同关闭，而暂停容器时，容器中运行的应用程序只会被暂停。我们可以简单地把容器的停止与暂停理解为电脑的关机与休眠。
#
# 暂停容器和恢复容器的方法很简单：
#
# ![image.png](attachment:9e17e811-dcf8-4ca1-8b6f-c9f0eb23b3b9.png)

# %%
#对应图片images/txt004_24.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sude docker ps -—1
CONTAINER ID IMAGE COMMAND CREATED
# Out:
#   File "<ipython-input-30-0448613e77dc>", line 2
#     S sude docker ps -—1
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_24.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# ![image.png](attachment:9d0f3a5a-e3fe-431c-9ec5-b2171c6f0558.png)

# %%
#对应图片images/txt004_25.jpg；想要获取 mycode 奖励，请勿删除此行注释。
STATUS PORTS NAMES
7013794de69c nginx:stable "nginx -g 'daemon off"
Up 2 seconds 80/tcp, 443/tcp web
S sudo docker pause web

web

$ sudo docker ps -l

CONTAINER ID IMAGE COMMAND
STATUS PORTS NAMES
7¢013794de69c nginx:stable "nginx -g 'daemon off"
Up 6 seconds (Paused) 80/tcp, 443/tcp web

S$ sudo docker unpause web
web

$ sudo docker ps -l

CONTAINER ID IMAGE COMMAND
STATUS PORTS NAMES
7¢013794de69c nginx:stable "nginx -g 'daemon off"

Up 9 seconds 80/tcp, 443/tcp web

35 seconds ago

CREATED

39 seconds ago

CREATED

42 seconds ago
# Out:
#   File "<ipython-input-31-485a27eae856>", line 2
#     STATUS PORTS NAMES
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_25.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# docker pause和docker unpause命令也可以同时作用于多个容器：
#
# ![image.png](attachment:49f800fd-6805-4585-9bd9-f63bc6ab926c.png)

# %%
#对应图片images/txt004_26.jpg；想要获取 mycode 奖励，请勿删除此行注释。
$ sudo docker pausenginx phpfpm mysql
nginx

phpfpm

mysql

S sudo docker unpause nginx phpfpm mysql
nginx

phpfpm

mysql
# Out:
#   File "<ipython-input-32-13609d213c5d>", line 2
#     $ sudo docker pausenginx phpfpm mysql
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_26.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# Docker容器暂停的原理是使用Linux的cgroup freezer将容器中的所有进程都挂起。与传统的挂起进程的方式不同，使用cgroup freezer挂起进程对进程来说是透明的，程序不会感知到自己已经被暂停，也不会感知到自己被恢复。由于没有传统挂起进程时传递给进程的SIGSTOP信号，所以进程不知道自己将会被挂起，也就没有机会对正在进行的工作进行保存。

# %% [markdown]
# ### 3.1.7 重启容器
#
# Docker还提供了docker restart命令用于重启容器。
#
# 重启容器的过程就是停止容器和再次启动容器的过程，相当于docker stop和docker start命令的组合，使用docker restart命令的方法也非常简单：
#
# ![image.png](attachment:51cdea75-44db-498e-b42b-93daa542d796.png)

# %%
#对应图片images/txt004_27.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S sudo docker restart web

web
# Out:
#   File "<ipython-input-33-b4723a1d55f3>", line 2
#     S sudo docker restart web
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_27.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00

# %% [markdown]
# ### 3.1.8 删除容器
#
# 因为Docker特有的镜像机制，在创建容器的过程中没有大型的IO操作，所以创建容器的过程是秒级的。因此，我们更倾向于随用随删，在停止程序所在的容器时，将容器一并删除。
#
# 使用docker rm命令可以删除容器：
#
# ![image.png](attachment:4a481529-66b7-4fb7-8504-147a8d6250b8.png)

# %%
#对应图片images/txt004_28.jpg；想要获取 mycode 奖励，请勿删除此行注释。
S$ sudo docker rm web

web
# Out:
#   File "<ipython-input-34-d83b3171d22a>", line 2
#     S$ sudo docker rm web
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_28.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 直接使用docker rm命令时，需要保证被删除的容器处于停止状态，正在运行中的容器是不会被删除的。如果需要删除正在运行的容器，需要携带-f或--force参数：
#
# ![image.png](attachment:7ad2471a-dda8-44b7-b1cb-5616fb908542.png)

# %%
#对应图片images/txt004_29.jpg；想要获取 mycode 奖励，请勿删除此行注释。
$ sudo docker ps

CONTAINER ID IMAGE COMMAND CREATED
STATUS PORTS NAMES

7013794de69c nginx:stable "nginx -g 'daemon off" About an hour ago
Up 6 seconds 80/tcp, 443/tcp web

$ sudo docker rm web

Error response from daemon: You cannot remove a running container 7c13794de69
cf816dade298f3fe3dblca7da580elea6114fb25c1012180ba36a. Stop the container before
attempting removal or use -f

$ sudo docker rm -f web

web
# Out:
#   File "<ipython-input-35-7d51ef486b07>", line 2
#     $ sudo docker ps
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 限时 mycode 任务：编程是一项注重实战的技能，立即尝试敲写代码，让自己熟能生巧。上方代码块中的文本是否和图片显示一致？欢迎您立即改写/修正并尝试运行。点击“存到 MyCode”，还有机会拿到学习时长 1-30u 的奖励。
#
# 图片：images/txt004_29.jpg；贡献者：虚位以待；最近更新：2020-08-31 20:00
#
# 当我们强制删除容器时，Docker会先向容器中的主进程发送SIGKILL信号，并强制停止容器，之后再对容器进行删除。

# %% [markdown]
# ## 3.2 连接到容器
