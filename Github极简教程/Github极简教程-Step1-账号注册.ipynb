# %% [markdown]
# 本教程基于Mac OS系统，Windows系统操作大体相似……
#
# # Github极简教程-Step1:账号注册
#
# 首先你需要[注册](https://github.com/join)一个 `github` 账号，如图所示，设置账号密码和邮箱，并进行账号验证，其它都可以使用默认设置。
#
# ![image.png](attachment:de9c8903-743d-47b1-aa3f-be112ea580db.png)
